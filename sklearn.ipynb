# %% [markdown]
# # LinearRegression

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

X = np.array([[50,200], [100,300], [150,400], [200,500]])  # 单位：平方米

y = np.array([200000, 300000, 400000, 500000])  # 单位：元

model = LinearRegression()

"""
第一个参数是矩阵n*m 第二个参数是向量n维向量
"""
model.fit(X, y)

print("斜率 (w1):", model.coef_[0])
print("斜率 (w2):", model.coef_[1])
print("截距 (w0):", model.intercept_)

# 画立体图
# 画立体图
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制数据点
ax.scatter(X[:,0], X[:,1], y, color='r', marker='o')

# 绘制拟合平面
x0_range = np.linspace(min(X[:,0]), max(X[:,0]), 100)
x1_range = np.linspace(min(X[:,1]), max(X[:,1]), 100)
x0_grid, x1_grid = np.meshgrid(x0_range, x1_range)
y_pred = model.predict(np.c_[x0_grid.ravel(), x1_grid.ravel()]).reshape(x0_grid.shape)
ax.plot_surface(x0_grid, x1_grid, y_pred, alpha=0.5)

ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('y')

plt.show()
# Out:
# 斜率 (w1): 400.0
# 斜率 (w2): 800.0
# 截距 (w0): 20000.0
